# %%
pip install tweepy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tweepy in /usr/local/lib/python3.8/dist-packages (3.10.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.8/dist-packages (from tweepy) (1.15.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from tweepy) (1.3.1)
# Requirement already satisfied: requests[socks]>=2.11.1 in /usr/local/lib/python3.8/dist-packages (from tweepy) (2.25.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from requests-oauthlib>=0.7.0->tweepy) (3.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests[socks]>=2.11.1->tweepy) (2022.12.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests[socks]>=2.11.1->tweepy) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests[socks]>=2.11.1->tweepy) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests[socks]>=2.11.1->tweepy) (2.10)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.8/dist-packages (from requests[socks]>=2.11.1->tweepy) (1.7.1)

# %%
# Imports the needed libraries
# You may need to install tweepy
import tweepy
import pandas as pd
import time

# %%
api_key = 'y3Ss7LEomTSRu1qGvydZZyqL0'
api_key_secret = 'ALiWGn8eRRk0BSP5WN8zMyYb8GQgdRqDfkd77YZ14HDj8XJB8a'
access_token = '34103544-mfZdwY9HzHW2PvRotpFzUfcp0MY55vf3RB3sKdPzG'
access_token_secret = 'bcGvdXw4YPDbOSKnHEsIdXzI2QsBGABf2f07R2kju22vg'
auth = tweepy.OAuthHandler(api_key, api_key_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth,wait_on_rate_limit=True)

# %%
# to get a keyword search returning 15 
# query = COVID
# tweet_mode extended contains the entire untruncated text of the Tweet
# _tweets
cursor = tweepy.Cursor(api.search, q="cricket", tweet_mode = 'extended').items(15)

# %%
for i in cursor:
 print(i.full_text)
# Out:
# @WG_RumblePants India was the number 1 team in all formats for 6 hours until it was discovered to be a drunken ICC glitch.
#
# Our joys are many but very short-lived as Indian cricket fans. None shorter than this one
# RT @SaeedGhani1: What a great game of cricket
# No matter who wins
# #KarachiKings #PeshawarZalmi
# #PSL2023
# RT @toisports: #INDvAUS #INDvsAUS #ViratKohli
#
# India vs Australia: Virat Kohli spends extra hours against spinners in the nets
#
# READ: htt…
# RT @cricketpakcompk: Bollywood actress, Urvashi Rautela,  posted a birthday message for Naseem Shah on Instagram 😲
#
# Read more: https://t.co…
# ~Senate committee hammers FAA chief on computer outage, safety incidents~
# https://t.co/YTGzs2jVFK
# #News #Information #Business #Travel #Food #Sports #Cricket #Student #Health #Infotech #WFH #Marketing
#  Senators grilled the head of the Federal Aviation Administration on Wedn... https://t.co/EFDP5fj8Lw
# RT @wwos: Some Warnie wizardry for your Wednesday. ❤️
#
# #9WWOS #cricket https://t.co/PsT5A3uUwr
# RT @iihtishamm: Stop posting things that aren’t related to cricket.
# RT @CricCrazyJohns: Number 1 Test team - India
# Number 1 T20I team - India
# Number 1 ODI team - India
# Number 1 T20 batter - Surya
# Number…
# RT @RealHa55an: - Congratulations Girls 🇵🇰
# @MuneebaAli17 has created history by becoming the first female cricketer to score a century for…
# Mr. VK for you Chetan Sharma is a late father figure for you. The issue for u is you are living rich celebrity life and that won’t work in athlete career. For you Cricket career is over but due to your stupid intentions to play play play makes u mad … https://t.co/1FqsF6BrUD
# RT @RCBTweets: While our coaching staff handle the cricket side of things, we couldn’t think of anyone better to guide our women cricketers…
# RT @patrick_kidd: When an international sex symbol met a famous actress… Fred Trueman with the mother of the groom at the wedding of his da…
# RT @DoRightMars: For years it’s been marketed as the most important meal of the day… Instead of us criticizing corporate greed and price go…
# RT @ArfaSays_: Ramiz Raja - "The interest of Imran Khan (when PM) increased in cricket when Pakistan defeated India in T20 WorldCup. IK als…
# RT @RealHa55an: - Congratulations Girls 🇵🇰
# @MuneebaAli17 has created history by becoming the first female cricketer to score a century for…

# %%
# to get a keyword search
# return a directory of available objects
cursor = tweepy.Cursor(api.search, q="cricket", tweet_mode = 'extended').items(1)
for i in cursor:
 print(dir(i))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_api', '_json', 'author', 'contributors', 'coordinates', 'created_at', 'destroy', 'display_text_range', 'entities', 'favorite', 'favorite_count', 'favorited', 'full_text', 'geo', 'id', 'id_str', 'in_reply_to_screen_name', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'is_quote_status', 'lang', 'metadata', 'parse', 'parse_list', 'place', 'retweet', 'retweet_count', 'retweeted', 'retweets', 'source', 'source_url', 'truncated', 'user']

# %%
# return tweets and create a series of empty lists
number_of_tweets = 20
tweets = []
likes = []
time= []
source = []
for i in tweepy.Cursor (api.search, q ="cricket", tweet_mode = 'extended', lang='en').items(20):
 tweets.append(i.full_text)
 likes.append (i.favorite_count)
 time.append (i.created_at)
 source.append (i.source)
source
# You can run this for each of your placeholders (i.e. tweets, likes, etc.)
# Out:
# ['Twitter Web App',
#  'Twitter for iPhone',
#  'Twitter Web App',
#  'Twitter for Android',
#  'TweetDeck',
#  'Twitter Web App',
#  'Twitter for iPhone',
#  'Twitter for Android',
#  'Twitter for Android',
#  'Twitter for Android',
#  'Twitter for iPhone',
#  'Twitter for iPhone',
#  'Twitter for Android',
#  'Twitter Web App',
#  'Twitter for Android',
#  'Microsoft Power Platform',
#  'TweetDeck',
#  'Twitter Web App',
#  'Twitter Web App',
#  'Twitter for iPhone']

# %%
# create a dataframe from the lists and output in table format
df = pd.DataFrame ({'tweets':tweets, 'likes':likes, "time": time, 'source':source})
df.head(7)
# Out:
#                                               tweets  likes  \
# 0  RT @patrick_kidd: When an international sex sy...      0
# 1  RT @RCBTweets: While our coaching staff handle...      0
# 2  Monday's #SecondXI squad includes plenty of @v...      0
# 3  Are you a cricket and baseball fan? Well we've...      0
# 4  RT @Aboutpakistan90: Beautiful Moments Of The ...      0
# 5  RT @ArfaSays_: The world cricket was trying to...      0
# 6  RT @ViratFanTeam: Virat Kohli's art picture at...      0
#
#                  time               source
# 0 2023-02-15 23:05:15   Twitter for iPhone
# 1 2023-02-15 23:05:04      Twitter Web App
# 2 2023-02-15 23:04:45      Twitter Web App
# 3 2023-02-15 23:04:44                Thryv
# 4 2023-02-15 23:04:43  Twitter for Android
# 5 2023-02-15 23:04:41  Twitter for Android
# 6 2023-02-15 23:04:22  Twitter for Android

# %%
# create dataframe with filtered results
df = df[~df.tweets.str.contains ("RT")]

# %%
# return last 3 records
print(df.tail(3))
# Out:
#                                                tweets  likes  \
# 17  Women's National Cricket League\nTasmania v We...      0
# 18  Asked for his opinion of his new son-in-law, T...      2
# 19  Test Cricket BACK in 2 hours and I’m convenien...      0
#
#                   time              source
# 17 2023-02-15 23:02:43     Twitter Web App
# 18 2023-02-15 23:02:33  Twitter for iPhone
# 19 2023-02-15 23:02:30  Twitter for iPhone

# %%
from google.colab import files

df.to_csv('tweets.txt')

files.download('tweets.txt')
